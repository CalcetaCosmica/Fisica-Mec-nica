# %% [markdown]
# # Parte I

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.array([0, 0.0388, 0.06765556, 0.1032778, 0.1373444, 0.1734111, 0.2083, 0.2431778, 0.2767778, 0.3078667, 0.3478, 0.3790556, 0.4108222, 0.4449444, 0.4756778, 0.5075889, 0.5413444, 0.5757667, 0.6108889, 0.6466889, 0.6795889, 0.7127444, 0.7461333, 0.7795778, 0.8141222, 0.8514556, 0.8813778, 0.9142333, 0.9516667, 0.9855556, 1.019711, 1.053044, 1.099311, 1.124, 1.156389, 1.188756, 1.218144, 1.253078, 1.287878, 1.320356, 1.356878, 1.388056, 1.422622, 1.458289, 1.490633, 1.521622, 1.557322, 1.591711, 1.624922, 1.6621, 1.6947, 1.727056, 1.760489, 1.794767, 1.830878, 1.864822, 1.895311, 1.930922, 1.963378, 1.996656, 2.035433, 2.071656, 2.100056, 2.131978, 2.166367, 2.198744, 2.235389, 2.268, 2.304911, 2.338444, 2.3671, 2.402267, 2.437022, 2.4765, 2.504533, 2.539567, 2.5707, 2.605333, 2.6395, 2.674322])
delta_p = np.array([0.01368547, 0.0202263, 0.03946348, 0.02623016, -0.00733513, -0.02958832, -0.00428399, 0.02880083, -0.0026724, -0.00985492, 0.02080228, -0.01536265, -0.0012676, 0.02277429, -0.00932365, -0.01752941, 0.00895168, 0.00348493, -0.00522146, 0.00067174, -0.01575535, 0.01750462, 0.0198965, -0.04283029, 0.01163003, 0.03392466, -0.02952012, 0.00921062, 0.00151317, -0.01288951, -0.00458196, 0.01431499, 0.00451824, -0.00471859, 0.02690376, -0.01280516, -0.01786703, 0.00027401, -0.00224959, -0.00359376, 0.02129545, -0.00113037, -0.01542084, 0.01218638, -0.00516041, -0.00176672, -0.00335405, -0.00976414, 0.02126707, 0.00201943, -0.01289982, 0.01656637, -0.01105386, -0.01016771, 0.03190505, -0.0183636, -0.01067788, -0.00343591, -0.00658193, 0.0290838, -0.00455044, -0.00166163, -0.0118793, 0.00178079, 0.00509636, 6.27e-06, -0.00486384, -0.00205364, 0.01087907, -0.006816894, 0.019464854, -0.01795311, -0.010923963, 0.021321445, -0.006155915, 0.002617145, 0.003249644, -0.010578496, 0.006724886])


t = t[:-1]


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p, marker='o', linestyle='-', color='b')
plt.title('Δp vs t \n Parte I')
plt.xlabel('t (s)')
plt.ylabel('Δp (kg*m/s)')
plt.grid(True)  

delta_p_deriv = np.gradient(delta_p, t)


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p_deriv, marker='o', linestyle='-', color='r')
plt.title('Derivada de Δp con respecto a t \n Parte I')
plt.xlabel('t (s)')
plt.ylabel('d(Δp)/dt')
plt.grid(True) 

plt.show()

# %% [markdown]
# # Parte II

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.array([0.03548889,0.06887778,0.06887778,0.1089444,0.1401889,0.1749333,0.2048444,0.2375,0.2712556,0.3049444,0.3425,0.3735889,0.4056556,0.4397667,0.4740333,0.5102111,0.5463889,0.5757333,0.6112111,0.6446,0.6794556,0.7129667,0.7494778,0.7792889,0.8109333,0.8460556,0.8804,0.9181111,0.9534889,0.9826889,1.017356,1.0485,1.081711,1.118122,1.154422,1.184678,1.216756,1.254333,1.284711,1.317922,1.351822,1.387378,1.418411,1.453556,1.488356,1.5239,1.561422,1.591011,1.621978,1.657144,1.691633,1.725533,1.764533,1.7927,1.824289,1.859211,1.895744,1.931667,1.964789,1.997178,2.028844,2.065467,2.097411,2.129344,2.1654,2.197711,2.2312,2.269111,2.301322,2.333133,2.3685])
delta_p = np.array([0.01011954,0.01783431,0.01783431,0.01654136,-0.01120817,-0.01290796,0.00997840999999999,-0.0162466,-0.02748233,0.03893846,0.04263639,-0.04033923,-0.02698699,0.02220702,-0.01739083,0.03542601,-0.000753029999999988,-0.01805165,0.01250557,-0.01096607,0.00536349999999999,-0.01706375,0.00657893000000001,0.01256968,-0.01315095,-0.01415217,0.00928441999999999,0.03318528,-0.01316853,-0.0226013,0.02582158,-0.0031028,-0.0285685,0.01144625,0.02201437,-0.01530898,0.01254381,-0.00166601,-0.0192797,0.00145465,0.02647125,-0.01987986,-0.02161007,0.02455831,-0.00992865999999999,0.00491467000000001,0.01936876,-0.02448526,-0.0895494,-0.042767014,0.087644444,0.01237565,-0.01172085,-0.02320585,-0.01362996,0.01283033,0.0143617,-0.01453147,-0.00219232999999999,0.00736563999999999,-0.000615600000000001,0.00945309,0.00960212,-0.020574,-0.01689884,0.01571138,0.01011027,-0.01167663,0.01306595,-0.05414168,])


t = t[:-1]

plt.figure(figsize=(10, 6))
plt.plot(t, delta_p, marker='o', linestyle='-', color='b')
plt.title('Δp vs t \n Parte II')
plt.xlabel('t (s)')
plt.ylabel('Δp (kg*m/s)')
plt.grid(True)  


delta_p_deriv = np.gradient(delta_p, t)


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p_deriv, marker='o', linestyle='-', color='r')
plt.title('Derivada de Δp con respecto a t \n Parte II')
plt.xlabel('t (s)')
plt.ylabel('d(Δp)/dt')
plt.grid(True)  

plt.show()

# %% [markdown]
# # Parte III

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.array([0,0.0312,0.0312,0.06405556,0.09745556,0.1323111,0.1679,0.2022111,0.2401556,0.2719556,0.3082444,0.3402667,0.3760667,0.4070667,0.4401333,0.4723,0.5045889,0.5397222,0.5809778,0.6149444,0.6442222,0.6827222,0.7109,0.7426,0.7887556,0.8177667,0.8471333,0.8792778,0.9131556,0.9453889,0.9858667,1.019078,1.049556,1.082878,1.1141,1.148344,1.184333,1.214122,1.249,1.2837,1.317444,1.350889,1.382722,1.418111,1.448967,1.485622,1.523544,1.555478,1.587889,1.618378,1.653522,1.689667,1.724811,1.757967,1.792578,1.823544,1.856456,1.892911,1.924167,1.958444,1.996878,2.030767,2.064922,2.095089])
delta_p = np.array([0.20088451,-0.03230248,-0.03230248,0.04550637,-0.00785411,-0.01323086,0.00784931,-0.00431696999999999,0.00251404,0.01336919,0.00374004999999999,-0.00520935,-0.00994764999999999,0.00434285,-0.01627535,0.01945148,-0.0129772,-0.03855393,0.0586803,0.0118276,-0.0234001,0.0321624,-0.04542713,-0.01107369,0.05565572,-0.03021652,-0.00110721,0.00680774999999999,-0.01573278,-0.00637426999999999,0.04396553,0.00281970000000001,-0.05039535,0.02049685,-0.00664814999999999,-0.00972439999999999,0.02166915,-0.00774604000000001,-0.01139998,-0.00300553999999999,0.00430506999999999,0.00289976,0.03075203,-0.04996703,-0.11547892,-0.01378634,0.07981243,0.03095567,-0.00627788999999999,-0.02326666,-0.00183953000000001,0.01066502,-0.02390607,-0.02337293,0.02565768,0.00853678000000001,0.01583748,-0.00492126,-0.03024106,0.01604332,0.00950591000000001,-0.01447079,-0.11626641])


t = t[:-1]

# Graficar
plt.figure(figsize=(10, 6))
plt.plot(t, delta_p, marker='o', linestyle='-', color='b')
plt.title('Δp vs t \n Parte III')
plt.xlabel('t (s)')
plt.ylabel('Δp (kg*m/s)')
plt.grid(True)  


delta_p_deriv = np.gradient(delta_p, t)


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p_deriv, marker='o', linestyle='-', color='r')
plt.title('Derivada de Δp con respecto a t \n Parte III')
plt.xlabel('t (s)')
plt.ylabel('d(Δp)/dt')
plt.grid(True)  

plt.show()

# %% [markdown]
# # Parte IV

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.array([0,0.029,0.029,0.0656,0.1009778,0.1353,0.1661667,0.2029333,0.2319,0.2668556,0.2973111,0.3355889,0.3666444,0.4054,0.4367444,0.4731111,0.5025667,0.5377222,0.5691778,0.6076111,0.6404111,0.6738,0.7054556,0.7397778,0.7748667,0.8132556,0.8409444,0.8787222,0.9078333,0.9458,0.9743333,1.014322,1.046256,1.086011,1.114667,1.1547,1.179711,1.214578,1.251267,1.286211,1.314889,1.351711,1.381344,1.419822,1.450733,1.485056,1.521233,1.564033,1.588833,1.621289,1.652578,1.692289,1.720556,1.758478,1.7889,1.827544,1.859211,1.890856,1.922544,1.9596,1.996044,2.029422,2.058178])
delta_p = np.array([0.0253,0.0241734254,0.0241734254,0.0127359939,-0.00153460050000001,-0.0127353709,0.0173283269,0.0100810065,-0.0094623967,-0.0124162564,-0.0070603888,0.0129319544,-0.00688390360000001,-0.0054728147,0.0159871075,0.0075269373,0.00195702360000001,-0.014659914,-0.0060646378,0.0124913178,-0.00308515170000001,0.00599355470000002,-0.0144237804,-0.0132670384,0.0289783208,0.00752630520000001,-0.00931378610000001,-0.0026576805,0.00105499629999999,-0.0049704273,-0.00417748670000001,0.0036977719,0.000620580300000001,0.00100356490000001,0.0116778659,0.0090042198,-0.0339743144,0.0047852221,0.0115583175,-0.00424617000000001,-0.000100279999999987,-0.01662955,0.000465109999999998,0.00759182000000001,-0.01309591,-0.00838721,0.01790395,0.00998263000000001,-0.0144379,-0.00226224000000001,0.00584590000000001,0.00446406,-0.00252082,-0.0122222,0.000813040000000001,0.01093173,-0.00043348,-0.00207993,-0.00641586,0.01184665,0.00283868,-0.02045678,])

t = t[:-1]


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p, marker='o', linestyle='-', color='b')
plt.title('Δp vs t \n Parte IV')
plt.xlabel('t (s)')
plt.ylabel('Δp (kg*m/s) ')
plt.grid(True)  


delta_p_deriv = np.gradient(delta_p, t)

# Graficar la derivada
plt.figure(figsize=(10, 6))
plt.plot(t, delta_p_deriv, marker='o', linestyle='-', color='r')
plt.title('Derivada de Δp con respecto a t \n Parte IV')
plt.xlabel('t (s)')
plt.ylabel('d(Δp)/dt')
plt.grid(True)  

plt.show()

# %% [markdown]
# # Parte V

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.array([0,0.03194444,0.03194444,0.06477778,0.1000889,0.1323889,0.1722889,0.2036333,0.2372778,0.2680889,0.3010778,0.3378333,0.3714333,0.4080667,0.4402333,0.4697667,0.5066444,0.5372222,0.5719778,0.6103556,0.6421,0.6701,0.7054111,0.7391111,0.7720667,0.8089333,0.8403444,0.8757222,0.9091556,0.9421556,0.9762222,1.010844,1.046967,1.081144,1.112733,1.149167,1.179844,1.214667,1.253578,1.284356,1.318889,1.352744,1.385378,1.417756])

delta_p = np.array([0.0406,0.04180545,0.04180545,-0.0111386,-0.0169122,-0.00286859999999999,7.07000000000069E-05,0.0174814,0.0037196,-0.0261348,0.00156669999999998,-0.00263739999999998,0.0232789,0.0185599,-0.0334565,0.0076999,0.0137624,-0.04059773,0.00961933,0.0477042,-0.0167576,-0.0208655,0.0132995,0.0029033,-0.0092459,0.000913499999999984,-0.01462388,0.01483888,-0.000479499999999994,-0.02025492,0.00584861999999998,0.00339760000000001,0.0197541,-0.00682109999999998,-0.01706784,0.01856494,-0.0209649,0.013857,0.0200817,-0.03542515,0.00914749000000002,-0.03820294,0.0199])

t = t[:-1]


plt.figure(figsize=(10, 6))
plt.plot(t, delta_p, marker='o', linestyle='-', color='b')
plt.title('Δp vs t \n Parte V')
plt.xlabel('t (s)')
plt.ylabel('Δp (kg*m/s)')
plt.grid(True)  


delta_p_deriv = np.gradient(delta_p, t)

plt.figure(figsize=(10, 6))
plt.plot(t, delta_p_deriv, marker='o', linestyle='-', color='r')
plt.title('Derivada de Δp con respecto a t \n Parte V')
plt.xlabel('t (s)')
plt.ylabel('d(Δp)/dt')
plt.grid(True)  

plt.show()
